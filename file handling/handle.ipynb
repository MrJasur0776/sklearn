# %%
print('hi, me and you ')
# Out:
# hi, me and you

# %%
x = 5
y = 3
if x +y == 8:
    print('x + y is 8')
# Out:
# x + y is 8

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# handle branch
print('asdf')
# Out:
# asdf

# %%
# main branch
print('main branch')
# Out:
# main branch
